# %%
import seaborn as sns
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import klib

# %% [markdown]
# ## klib.describe - functions for visualizing datasets
# - klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# - klib.corr_mat(df) # returns a color-encoded correlation matrix
# - klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# - klib.dist_plot(df) # returns a distribution plot for every numeric feature
# - klib.missingval_plot(df) # returns a figure containing information about missing values

# %%
klib.cat_plot(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_60108/582943365.py in <module>
# ----> 1 klib.cat_plot(df)
#
# ~/anaconda3/lib/python3.7/site-packages/klib/describe.py in cat_plot(data, figsize, top, bottom, bar_color_top, bar_color_bottom)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# ~/anaconda3/lib/python3.7/site-packages/klib/describe.py in <listcomp>(.0)
#     116         data[col] = data[col].rolling(2, min_periods=1).mean()
#     117
# --> 118         value_counts_idx_top = [elem[:20] for elem in value_counts_idx_top]
#     119         value_counts_idx_bot = [elem[:20] for elem in value_counts_idx_bot]
#     120         sum_top = sum(value_counts_top)
#
# TypeError: 'bool' object is not subscriptable

# %%
klib.corr_mat(df)
# Out:
# <style  type="text/css" >
# #T_babd6_row0_col0,#T_babd6_row0_col4,#T_babd6_row0_col5,#T_babd6_row1_col1,#T_babd6_row1_col3,#T_babd6_row1_col4,#T_babd6_row1_col6,#T_babd6_row1_col7,#T_babd6_row2_col2,#T_babd6_row2_col5,#T_babd6_row2_col6,#T_babd6_row2_col7,#T_babd6_row3_col1,#T_babd6_row3_col3,#T_babd6_row3_col4,#T_babd6_row3_col5,#T_babd6_row4_col0,#T_babd6_row4_col1,#T_babd6_row4_col3,#T_babd6_row4_col4,#T_babd6_row4_col5,#T_babd6_row5_col0,#T_babd6_row5_col2,#T_babd6_row5_col3,#T_babd6_row5_col4,#T_babd6_row5_col5,#T_babd6_row6_col1,#T_babd6_row6_col2,#T_babd6_row6_col6,#T_babd6_row6_col7,#T_babd6_row7_col1,#T_babd6_row7_col2,#T_babd6_row7_col6,#T_babd6_row7_col7{
#             color:  None;
#         }#T_babd6_row0_col1,#T_babd6_row0_col2,#T_babd6_row0_col3,#T_babd6_row0_col6,#T_babd6_row0_col7,#T_babd6_row1_col0,#T_babd6_row1_col2,#T_babd6_row1_col5,#T_babd6_row2_col0,#T_babd6_row2_col1,#T_babd6_row2_col3,#T_babd6_row2_col4,#T_babd6_row3_col0,#T_babd6_row3_col2,#T_babd6_row3_col6,#T_babd6_row3_col7,#T_babd6_row4_col2,#T_babd6_row4_col6,#T_babd6_row4_col7,#T_babd6_row5_col1,#T_babd6_row5_col6,#T_babd6_row5_col7,#T_babd6_row6_col0,#T_babd6_row6_col3,#T_babd6_row6_col4,#T_babd6_row6_col5,#T_babd6_row7_col0,#T_babd6_row7_col3,#T_babd6_row7_col4,#T_babd6_row7_col5{
#             color:  #FF3344;
#         }</style><table id="T_babd6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >survived</th>        <th class="col_heading level0 col1" >pclass</th>        <th class="col_heading level0 col2" >age</th>        <th class="col_heading level0 col3" >sibsp</th>        <th class="col_heading level0 col4" >parch</th>        <th class="col_heading level0 col5" >fare</th>        <th class="col_heading level0 col6" >adult_male</th>        <th class="col_heading level0 col7" >alone</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_babd6_level0_row0" class="row_heading level0 row0" >survived</th>
#                         <td id="T_babd6_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_babd6_row0_col1" class="data row0 col1" >-0.34</td>
#                         <td id="T_babd6_row0_col2" class="data row0 col2" >-0.08</td>
#                         <td id="T_babd6_row0_col3" class="data row0 col3" >-0.04</td>
#                         <td id="T_babd6_row0_col4" class="data row0 col4" >0.08</td>
#                         <td id="T_babd6_row0_col5" class="data row0 col5" >0.26</td>
#                         <td id="T_babd6_row0_col6" class="data row0 col6" >-0.56</td>
#                         <td id="T_babd6_row0_col7" class="data row0 col7" >-0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row1" class="row_heading level0 row1" >pclass</th>
#                         <td id="T_babd6_row1_col0" class="data row1 col0" >-0.34</td>
#                         <td id="T_babd6_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_babd6_row1_col2" class="data row1 col2" >-0.37</td>
#                         <td id="T_babd6_row1_col3" class="data row1 col3" >0.08</td>
#                         <td id="T_babd6_row1_col4" class="data row1 col4" >0.02</td>
#                         <td id="T_babd6_row1_col5" class="data row1 col5" >-0.55</td>
#                         <td id="T_babd6_row1_col6" class="data row1 col6" >0.09</td>
#                         <td id="T_babd6_row1_col7" class="data row1 col7" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row2" class="row_heading level0 row2" >age</th>
#                         <td id="T_babd6_row2_col0" class="data row2 col0" >-0.08</td>
#                         <td id="T_babd6_row2_col1" class="data row2 col1" >-0.37</td>
#                         <td id="T_babd6_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_babd6_row2_col3" class="data row2 col3" >-0.31</td>
#                         <td id="T_babd6_row2_col4" class="data row2 col4" >-0.19</td>
#                         <td id="T_babd6_row2_col5" class="data row2 col5" >0.10</td>
#                         <td id="T_babd6_row2_col6" class="data row2 col6" >0.28</td>
#                         <td id="T_babd6_row2_col7" class="data row2 col7" >0.20</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row3" class="row_heading level0 row3" >sibsp</th>
#                         <td id="T_babd6_row3_col0" class="data row3 col0" >-0.04</td>
#                         <td id="T_babd6_row3_col1" class="data row3 col1" >0.08</td>
#                         <td id="T_babd6_row3_col2" class="data row3 col2" >-0.31</td>
#                         <td id="T_babd6_row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_babd6_row3_col4" class="data row3 col4" >0.41</td>
#                         <td id="T_babd6_row3_col5" class="data row3 col5" >0.16</td>
#                         <td id="T_babd6_row3_col6" class="data row3 col6" >-0.25</td>
#                         <td id="T_babd6_row3_col7" class="data row3 col7" >-0.58</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row4" class="row_heading level0 row4" >parch</th>
#                         <td id="T_babd6_row4_col0" class="data row4 col0" >0.08</td>
#                         <td id="T_babd6_row4_col1" class="data row4 col1" >0.02</td>
#                         <td id="T_babd6_row4_col2" class="data row4 col2" >-0.19</td>
#                         <td id="T_babd6_row4_col3" class="data row4 col3" >0.41</td>
#                         <td id="T_babd6_row4_col4" class="data row4 col4" >1.00</td>
#                         <td id="T_babd6_row4_col5" class="data row4 col5" >0.22</td>
#                         <td id="T_babd6_row4_col6" class="data row4 col6" >-0.35</td>
#                         <td id="T_babd6_row4_col7" class="data row4 col7" >-0.58</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row5" class="row_heading level0 row5" >fare</th>
#                         <td id="T_babd6_row5_col0" class="data row5 col0" >0.26</td>
#                         <td id="T_babd6_row5_col1" class="data row5 col1" >-0.55</td>
#                         <td id="T_babd6_row5_col2" class="data row5 col2" >0.10</td>
#                         <td id="T_babd6_row5_col3" class="data row5 col3" >0.16</td>
#                         <td id="T_babd6_row5_col4" class="data row5 col4" >0.22</td>
#                         <td id="T_babd6_row5_col5" class="data row5 col5" >1.00</td>
#                         <td id="T_babd6_row5_col6" class="data row5 col6" >-0.18</td>
#                         <td id="T_babd6_row5_col7" class="data row5 col7" >-0.27</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row6" class="row_heading level0 row6" >adult_male</th>
#                         <td id="T_babd6_row6_col0" class="data row6 col0" >-0.56</td>
#                         <td id="T_babd6_row6_col1" class="data row6 col1" >0.09</td>
#                         <td id="T_babd6_row6_col2" class="data row6 col2" >0.28</td>
#                         <td id="T_babd6_row6_col3" class="data row6 col3" >-0.25</td>
#                         <td id="T_babd6_row6_col4" class="data row6 col4" >-0.35</td>
#                         <td id="T_babd6_row6_col5" class="data row6 col5" >-0.18</td>
#                         <td id="T_babd6_row6_col6" class="data row6 col6" >1.00</td>
#                         <td id="T_babd6_row6_col7" class="data row6 col7" >0.40</td>
#             </tr>
#             <tr>
#                         <th id="T_babd6_level0_row7" class="row_heading level0 row7" >alone</th>
#                         <td id="T_babd6_row7_col0" class="data row7 col0" >-0.20</td>
#                         <td id="T_babd6_row7_col1" class="data row7 col1" >0.14</td>
#                         <td id="T_babd6_row7_col2" class="data row7 col2" >0.20</td>
#                         <td id="T_babd

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %% [markdown]
# ## klib.clean - functions for cleaning datasets
# - klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# - klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
# - klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
# - klib.drop_missing(df) # drops missing values, also called in data_cleaning()
# - klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
# - klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (784, 15)Remaining NAs: 692
#
# Changes:
# Dropped rows: 107
#      of which 107 duplicates. (Rows: [47, 76, 77, 87, 95, 101, 121, 133, 173, 196, 198, 201, 213, 223, 241, 260, 274, 295, 300, 304, 313, 320, 324, 335, 343, 354, 355, 358, 359, 364, 368, 384, 409, 410, 413, 418, 420, 425, 428, 431, 454, 459, 464, 466, 470, 476, 481, 485, 488, 490, 494, 500, 511, 521, 522, 526, 531, 560, 563, 564, 568, 573, 588, 589, 598, 601, 612, 613, 614, 635, 636, 640, 641, 644, 646, 650, 656, 666, 674, 692, 696, 709, 732, 733, 734, 738, 739, 757, 758, 760, 773, 790, 792, 800, 808, 832, 837, 838, 844, 846, 859, 863, 870, 877, 878, 884, 886])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 177
# Reduced memory by at least: 0.06 MB (-75.0%)
#      survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.250000        S  Third
# 1           1       1  female  38.0      1      0  71.283302        C  First
# 2           1       3  female  26.0      0      0   7.925000        S  Third
# 3           1       1  female  35.0      1      0  53.099998        S  First
# 4           0       3    male  35.0      0      0   8.050000        S  Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...    ...
# 779         0       3  female  39.0      0      5  29.125000        Q  Third
# 780         1       1  female  19.0      0      0  30.000000        S  First
# 781         0       3  female   NaN      1      2  23.450001        S  Third
# 782         1       1    male  26.0      0      0  30.000000        C  First
# 783         0       3    male  32.0      0      0   7.750000        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 779  woman       False  NaN   Queenstown    no  False
# 780  woman       False    B  Southampton   yes   True
# 781  woman       False  NaN  Southampton    no  False
# 782    man        True    C    Cherbourg   yes   True
# 783    man        True  NaN   Queenstown    no   True
#
# [784 rows x 15 columns]

# %%
klib.clean_column_names(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
klib.convert_datatypes(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch       fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.250000        S   Third
# 1           1       1  female  38.0      1      0  71.283302        C   First
# 2           1       3  female  26.0      0      0   7.925000        S   Third
# 3           1       1  female  35.0      1      0  53.099998        S   First
# 4           0       3    male  35.0      0      0   8.050000        S   Third
# ..        ...     ...     ...   ...    ...    ...        ...      ...     ...
# 886         0       2    male  27.0      0      0  13.000000        S  Second
# 887         1       1  female  19.0      0      0  30.000000        S   First
# 888         0       3  female   NaN      1      2  23.450001        S   Third
# 889         1       1    male  26.0      0      0  30.000000        C   First
# 890         0       3    male  32.0      0      0   7.750000        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ## klib.preprocess - functions for data preprocessing (feature selection, scaling, ...)
# - klib.train_dev_test_split(df) # splits a dataset and a label into train, optionally dev and test sets
# - klib.feature_selection_pipe() # provides common operations for feature selection
# - klib.num_pipe() # provides common operations for preprocessing of numerical data
# - klib.cat_pipe() # provides common operations for preprocessing of categorical data
# - klib.preprocess.ColumnSelector() # selects num or cat columns, ideal for a Feature Union or Pipeline
# - klib.preprocess.PipeInfo() # prints out the shape of the data at the specified step of a Pipeline
